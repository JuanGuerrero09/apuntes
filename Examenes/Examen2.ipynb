# %% [markdown]
# # Examen 2

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('./Data Examen 2/water_potability.csv')
df
# Out:
#             ph    Hardness        Solids  Chloramines     Sulfate  \
# 0          NaN  204.890455  20791.318981     7.300212  368.516441
# 1     3.716080  129.422921  18630.057858     6.635246         NaN
# 2     8.099124  224.236259  19909.541732     9.275884         NaN
# 3     8.316766  214.373394  22018.417441     8.059332  356.886136
# 4     9.092223  181.101509  17978.986339     6.546600  310.135738
# ...        ...         ...           ...          ...         ...
# 3271  4.668102  193.681735  47580.991603     7.166639  359.948574
# 3272  7.808856  193.553212  17329.802160     8.061362         NaN
# 3273  9.419510  175.762646  33155.578218     7.350233         NaN
# 3274  5.126763  230.603758  11983.869376     6.303357         NaN
# 3275  7.874671  195.102299  17404.177061     7.509306         NaN
#
#       Conductivity  Organic_carbon  Trihalomethanes  Turbidity  Potability
# 0       564.308654       10.379783        86.990970   2.963135           0
# ...

# %%
#1. ¿Cuántas filas de información tiene?
filas = df.size
filas
# Out:
# 32760

# %%
#2. ¿Cual es el mínimo, máximo, cuantil 25% y cuantil 75% en el Dataframe?
info = df.describe()
data = info.loc[["min", "max", "25%", "75%"]]
data
# Out:
#             ph    Hardness        Solids  Chloramines     Sulfate  \
# min   0.000000   47.432000    320.942611     0.352000  129.000000
# max  14.000000  323.124000  61227.196008    13.127000  481.030642
# 25%   6.093092  176.850538  15666.690297     6.127421  307.699498
# 75%   8.062066  216.667456  27332.762127     8.114887  359.950170
#
#      Conductivity  Organic_carbon  Trihalomethanes  Turbidity  Potability
# min    181.483754        2.200000         0.738000   1.450000         0.0
# max    753.342620       28.300000       124.000000   6.739000         1.0
# 25%    365.734414       12.065801        55.844536   3.439711         0.0
# 75%    481.792304       16.557652        77.337473   4.500320         1.0

# %%
#3. Obtenga una matriz de correlación entre los parámetros
corr = data.corr()
print(corr)
# Out:
#                        ph  Hardness    Solids  Chloramines   Sulfate  \
# ph               1.000000  0.998720  0.975522     0.999317  0.994334
# Hardness         0.998720  1.000000  0.963633     0.999805  0.998438
# Solids           0.975522  0.963633  1.000000     0.968279  0.947620
# Chloramines      0.999317  0.999805  0.968279     1.000000  0.997366
# Sulfate          0.994334  0.998438  0.947620     0.997366  1.000000
# Conductivity     0.991785  0.985043  0.994638     0.988151  0.974651
# Organic_carbon   0.997858  0.993780  0.987313     0.995662  0.986310
# Trihalomethanes  0.998662  0.999519  0.967247     0.999815  0.997486
# Turbidity        0.997494  0.994396  0.984549     0.996290  0.988003
# Potability       0.798671  0.799564  0.809594     0.806699  0.798048
#
#                  Conductivity  Organic_carbon  Trihalomethanes  Turbidity  \
# ph                   0.991785        0.997858         0.998662   0.997494
# ...

# %%
corr
# Out:
#                        ph  Hardness    Solids  Chloramines   Sulfate  \
# ph               1.000000  0.998720  0.975522     0.999317  0.994334
# Hardness         0.998720  1.000000  0.963633     0.999805  0.998438
# Solids           0.975522  0.963633  1.000000     0.968279  0.947620
# Chloramines      0.999317  0.999805  0.968279     1.000000  0.997366
# Sulfate          0.994334  0.998438  0.947620     0.997366  1.000000
# Conductivity     0.991785  0.985043  0.994638     0.988151  0.974651
# Organic_carbon   0.997858  0.993780  0.987313     0.995662  0.986310
# Trihalomethanes  0.998662  0.999519  0.967247     0.999815  0.997486
# Turbidity        0.997494  0.994396  0.984549     0.996290  0.988003
# Potability       0.798671  0.799564  0.809594     0.806699  0.798048
#
#                  Conductivity  Organic_carbon  Trihalomethanes  Turbidity  \
# ph                   0.991785        0.997858         0.998662   0.997494
# ...

# %%
total_nan = df.isna().sum().sum()
print(f"Total NaN en el DataFrame: {total_nan}")
# Contar cuántos NaN hay por cada columna
nan_por_columna = df.isna().sum()
print(nan_por_columna)
# Out:
# Total NaN en el DataFrame: 1434
# ph                 491
# Hardness             0
# Solids               0
# Chloramines          0
# Sulfate            781
# Conductivity         0
# Organic_carbon       0
# Trihalomethanes    162
# Turbidity            0
# Potability           0
# dtype: int64

# %%
# Debido a que hay na en Sulfate, ph y Trihalomethanes se procede a drop na en estos
sulf = df["Sulfate"].dropna()
ph = df["ph"].dropna()
trihalo = df["Trihalomethanes"].dropna()

data_without_nan = pd.DataFrame({"Sulfate": sulf, "ph": ph, "Trihalomethanes": trihalo})
data_without_nan
total_nan = data_without_nan.isna().sum().sum()
print(f"Total NaN en el DataFrame: {total_nan}")
# Contar cuántos NaN hay por cada columna
nan_por_columna = data_without_nan.isna().sum()
print(nan_por_columna)
# Out:
# Total NaN en el DataFrame: 1407
# Sulfate            772
# ph                 482
# Trihalomethanes    153
# dtype: int64

# %%
# Debido a que hay na en Sulfate, ph y Trihalomethanes se procede a drop na en estos
data_without_nan = df[["Sulfate", "ph", "Trihalomethanes"]].dropna()
data_without_nan
# Out:
#          Sulfate         ph  Trihalomethanes
# 3     356.886136   8.316766       100.341674
# 4     310.135738   9.092223        31.997993
# 5     326.678363   5.584087        54.917862
# 6     393.663396  10.223862        84.603556
# 7     303.309771   8.635849        62.798309
# ...          ...        ...              ...
# 3267  312.931022   8.989900        55.069304
# 3268  304.510230   6.702547        28.878601
# 3269  258.930600  11.491011        41.558501
# 3270  345.700257   6.069616        60.419921
# 3271  359.948574   4.668102        66.687695
#
# [2011 rows x 3 columns]

# %%
total_nan = data_without_nan.isna().sum().sum()
print(f"Total NaN en el DataFrame: {total_nan}")
# Contar cuántos NaN hay por cada columna
nan_por_columna = data_without_nan.isna().sum()
print(nan_por_columna)
print("ph" in data_without_nan)
# Out:
# Total NaN en el DataFrame: 0
# Sulfate            0
# ph                 0
# Trihalomethanes    0
# dtype: int64
# True

# %%
# Generar los gráficos box-plot de todos los parámetros con títulos y etiquetas
boxplot_data = df
fig, axs = plt.subplots(5,2, figsize=(8,20))
titles = list(df.columns)
for i, title in enumerate(titles):
    row, col = divmod(i, 2)
    if title in data_without_nan:
        axs[row, col].boxplot(data_without_nan[title])
    else:
        axs[row, col].boxplot(boxplot_data[title])
    axs[row, col].set_title(title)
    axs[row, col].grid(axis="x", linestyle='-')
plt.show()
df.describe()
# Out:
#                 ph     Hardness        Solids  Chloramines      Sulfate  \
# count  2785.000000  3276.000000   3276.000000  3276.000000  2495.000000
# mean      7.080795   196.369496  22014.092526     7.122277   333.775777
# std       1.594320    32.879761   8768.570828     1.583085    41.416840
# min       0.000000    47.432000    320.942611     0.352000   129.000000
# 25%       6.093092   176.850538  15666.690297     6.127421   307.699498
# 50%       7.036752   196.967627  20927.833607     7.130299   333.073546
# 75%       8.062066   216.667456  27332.762127     8.114887   359.950170
# max      14.000000   323.124000  61227.196008    13.127000   481.030642
#
#        Conductivity  Organic_carbon  Trihalomethanes    Turbidity   Potability
# count   3276.000000     3276.000000      3114.000000  3276.000000  3276.000000
# mean     426.205111       14.284970        66.396293     3.966786     0.390110
# std       80.824064        3.308162        16.175008     0.780382     0.487849
# ...

# %%
# Generar los gráficos box-plot de todos los parámetros con títulos y etiquetas
boxplot_data = df
fig, axs = plt.subplots(5,2, figsize=(8,25))
titles = list(df.columns)
for i, title in enumerate(titles):
    row, col = divmod(i, 2)
    if title in data_without_nan:
        axs[row, col].hist(data_without_nan[title], label="Hola")
    else:
        axs[row, col].hist(boxplot_data[title])
    axs[row, col].set_title(title)
    axs[row, col].set_xlabel("Valor")
    axs[row, col].set_ylabel("Frecuencia")
    axs[row, col].grid( linestyle='-')
plt.tight_layout()
plt.show()

# %%
import seaborn as sns
sns.histplot(data_without_nan["Sulfate"].values)

# Generar los gráficos box-plot de todos los parámetros con títulos y etiquetas
boxplot_data = df
fig, axs = plt.subplots(5,2, figsize=(8,25))
titles = list(df.columns)
for i, title in enumerate(titles):
    row, col = divmod(i, 2)
    if title in data_without_nan:
        sns.histplot(data_without_nan[title].values, ax=axs[row, col], kde=True)
    else:
        sns.histplot(boxplot_data[title].values, ax=axs[row, col], kde=True)
    axs[row, col].set_title(title)
    axs[row, col].set_xlabel("Valor")
    axs[row, col].set_ylabel("Frecuencia")
    axs[row, col].grid( linestyle='-')
plt.tight_layout()
plt.show()

# %%
# %pip install rasterio
import rasterio
# lsFile = rasterio.open('./Data Examen 2/Landsat8/2020-01-27-00_00_2020-01-27-23_59_Sentinel-2_L2A_B04_(Raw).tif')
lsFile = rasterio.open('./Data Examen 2/Landsat8/2020-01-27-00_00_2020-01-27-23_59_Sentinel-2_L2A_B04_(Raw).tiff')

# %%
print(lsFile.name)  
print(lsFile.mode)  
print(lsFile.closed )  
print( lsFile.driver)  
# Indicar el número de filas y columnas del raster (band 04)
print(f"El número de filas es: {lsFile.height}")
print(f"El número de columnas es: {lsFile.width}")
print(f"El número de bandas es: {lsFile.count}")
print(f"La altura es: {lsFile.height} píxeles")
# Out:
# ./Data Examen 2/Landsat8/2020-01-27-00_00_2020-01-27-23_59_Sentinel-2_L2A_B04_(Raw).tiff
# r
# False
# GTiff
# El número de filas es: 954
# El número de columnas es: 298
# El número de bandas es: 2
# La altura es: 954 píxeles

# %%
# Plotear la banda 04.

# %%
# Indicar el sistema de referencia de las imágenes.
print(f"El sistema de referencia es: {lsFile.crs}")
# Indicar la resolución espacial de las imágenes.
print(f"La resolución espacial es: {lsFile.res}")
# Indicar el tamaño de píxel de las imágenes.
print(f"El tamaño de píxel es: {lsFile.transform}")
# Out:
# El sistema de referencia es: EPSG:4326
# La resolución espacial es: (0.00017972600540053956, 0.00016649141203214603)
# El tamaño de píxel es: | 0.00, 0.00, 89.08|
# | 0.00,-0.00, 22.29|
# | 0.00, 0.00, 1.00|

# %%
# Realizar una representación múltiple de las bandas.

# %%
# Plotear el NDVI.
